# %%
import matplotlib.pyplot as plt
import random
from supervenn import supervenn

p = 30
sets = [set(random.choices(range(p), k=random.randint(p//2, p))) for _ in range(p)]

plt.figure(figsize=(16,9), dpi=90)
supervenn(sets, set_annotations=['']*p, side_plots=False);
